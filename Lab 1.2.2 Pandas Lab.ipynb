# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
#import io
#df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))

# %%
df = pd.read_csv("Employee-attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
data
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
# A:
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
#pd.set_option('display.max_columns', 35)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
pd.reset_option("^display")

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A:
df.JobRole.unique
#Job title not present in dataframe
# Out:
# <bound method Series.unique of 0                 Sales Executive
# 1              Research Scientist
# 2           Laboratory Technician
# 3              Research Scientist
# 4           Laboratory Technician
#                   ...
# 1465        Laboratory Technician
# 1466    Healthcare Representative
# 1467       Manufacturing Director
# 1468              Sales Executive
# 1469        Laboratory Technician
# Name: JobRole, Length: 1470, dtype: object>

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A:
df.JobRole.value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
df['JobRole'].value_counts() #alternatively
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
def row_count(column_name):
    number_of_rows = len(df[column_name])
    number_of_unique_rows = df[column_name].value_counts()
    return number_of_rows, number_of_unique_rows

print(row_count('JobRole'))
# Out:
# (1470, Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64)

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A:
df.Age.describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:
df.describe(include=[np.number])
#can just do describe() - also only take integers and flows
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#assign employeeNumber as index
df_index = df.set_index('EmployeeNumber')

# %%
df_index.tail()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 2061            Research & Development                23          2
# 2062            Research & Development                 6          1
# 2064            Research & Development                 4          3
# 2065                             Sales                 2          3
# 2068            Research & Development                 8          3
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# ...

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:
df_index.loc[2065,:]
# Out:
# Age                                        49
# Attrition                                  No
# BusinessTravel              Travel_Frequently
# DailyRate                                1023
# Department                              Sales
# DistanceFromHome                            2
# Education                                   3
# EducationField                        Medical
# EmployeeCount                               1
# EnvironmentSatisfaction                     4
# Gender                                   Male
# HourlyRate                                 63
# JobInvolvement                              2
# JobLevel                                    2
# JobRole                       Sales Executive
# JobSatisfaction                             2
# MaritalStatus                         Married
# MonthlyIncome                            5390
# MonthlyRate                             13243
# NumCompaniesWorked                          2
# ...

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:
df_index_sort = df_index.sort_index(ascending=True)

# %%
df_index_sort.head()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
# 5               Research & Development                 3          4
# 7               Research & Development                 2          1
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:
df_by_age = df_index_sort.sort_values(by='Age')
df_by_age
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1839             18        No         Non-Travel       1431
# 614              18       Yes  Travel_Frequently       1306
# 1368             18        No         Non-Travel       1124
# 411              18        No      Travel_Rarely        812
# 405              18       Yes      Travel_Rarely        230
# ...             ...       ...                ...        ...
# 732              60        No      Travel_Rarely       1179
# 573              60        No  Travel_Frequently       1499
# 549              60        No      Travel_Rarely        422
# 1233             60        No      Travel_Rarely        696
# 1697             60        No      Travel_Rarely        370
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1839            Research & Development                14          3
# 614                              Sales                 5          3
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A: select rows by age 60
df_by_age[df_by_age['Age'] == 18]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1839             18        No         Non-Travel       1431
# 614              18       Yes  Travel_Frequently       1306
# 1368             18        No         Non-Travel       1124
# 411              18        No      Travel_Rarely        812
# 405              18       Yes      Travel_Rarely        230
# 1624             18       Yes  Travel_Frequently        544
# 1012             18        No         Non-Travel        287
# 1156             18       Yes         Non-Travel        247
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1839            Research & Development                14          3
# 614                              Sales                 5          3
# 1368            Research & Development                 1          3
# 411                              Sales                10          3
# ...

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
df.loc[df['JobRole'] == 'Manager']
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 18     53        No      Travel_Rarely       1219                   Sales
# 25     53        No      Travel_Rarely       1282  Research & Development
# 29     46        No      Travel_Rarely        705                   Sales
# 65     55        No      Travel_Rarely        836  Research & Development
# 105    59        No         Non-Travel       1420         Human Resources
# ...   ...       ...                ...        ...                     ...
# 1351   48        No  Travel_Frequently        117  Research & Development
# 1374   58        No      Travel_Rarely        605                   Sales
# 1401   55        No      Travel_Rarely        189         Human Resources
# 1437   39        No         Non-Travel        105  Research & Development
# 1443   42        No      Travel_Rarely        300  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
# A: No Job_Title column, will use JobRole Sales Executive instead
df_by_job = df_by_age.query('JobRole == "Sales Executive"')
df_by_job
# Out:
#                 Age Attrition     BusinessTravel  DailyRate Department  \
# EmployeeNumber
# 720              24       Yes      Travel_Rarely        693      Sales
# 128              24        No      Travel_Rarely       1353      Sales
# 507              24        No      Travel_Rarely       1371      Sales
# 1445             24        No      Travel_Rarely       1476      Sales
# 885              25        No      Travel_Rarely        583      Sales
# ...             ...       ...                ...        ...        ...
# 91               59        No  Travel_Frequently       1225      Sales
# 81               59        No      Travel_Rarely       1435      Sales
# 732              60        No      Travel_Rarely       1179      Sales
# 573              60        No  Travel_Frequently       1499      Sales
# 1233             60        No      Travel_Rarely        696      Sales
#
#                 DistanceFromHome  Education EducationField  EmployeeCount  \
# EmployeeNumber
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:
df_by_job.groupby(by=['Age']).sum()
# Out:
#      DailyRate  DistanceFromHome  Education  EmployeeCount  \
# Age
# 24        4893                20          9              4
# 25        8617               114         21             10
# 26        8070               133         25              9
# 27        9655                73         25             11
# 28        6332                72         28              9
# 29        9728               137         30             13
# 30       14831               241         49             16
# 31       13582               191         59             18
# 32       14735               157         61             19
# 33       12990               175         58             18
# 34       18613               202         61             21
# 35       17592               207         68             20
# 36       15802               143         65             19
# 37        6512                76         34             10
# 38        9157                88         42             14
# ...

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
# A:
plt.hist(df['Age'])
# Out:
# (array([ 57., 105., 224., 265., 255., 217., 131.,  92.,  77.,  47.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fb454cb8e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fb454cbfa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fb454cb550>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fb454da6a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fb454daa00>],
#  'means': []}

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
plt.scatter(df['Age'],df['TotalWorkingYears'])

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A: No store_name, use department instead
plt.hist(df['Department'])
# Out:
# (array([446.,   0.,   0.,   0.,   0., 961.,   0.,   0.,   0.,  63.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A:
a = stats.describe(df['Age'])
pd.DataFrame([a],columns=a._fields)
# Out:
#    nobs    minmax      mean   variance  skewness  kurtosis
# 0  1470  (18, 60)  36.92381  83.455049  0.412864 -0.406851

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
